# %%
# !pip install rdkit-pypi tmap
# !pip install git+https://github.com/reymond-group/map4@v1.0
# !git clone https://github.com/Medicine-Artificial-Intelligence/Similarity_screen_apelin.git
# Out:
# Collecting rdkit-pypi
#   Downloading rdkit_pypi-2022.9.5-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (29.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 29.4/29.4 MB 12.8 MB/s eta 0:00:00
# Collecting tmap
#   Downloading tmap-1.2.1.tar.gz (494 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 495.0/495.0 kB 17.2 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from rdkit-pypi) (1.22.4)
# Requirement already satisfied: Pillow in /usr/local/lib/python3.10/dist-packages (from rdkit-pypi) (8.4.0)
# Requirement already satisfied: statsmodels>=0.9.0 in /usr/local/lib/python3.10/dist-packages (from tmap) (0.13.5)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from tmap) (4.65.0)
# Requirement already satisfied: scikit-learn>=0.19.1 in /usr/local/lib/python3.10/dist-packages (from tmap) (1.2.2)
# Requirement already satisfied: matplotlib>=2.2.2 in /usr/local/lib/python3.10/dist-packages (from tmap) (3.7.1)
# Collecting networkx==2.2 (from tmap)
#   Downloading networkx-2.2.zip (1.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 31.6 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: pandas>=0.23.0 in /usr/local/lib/python3.10/dist-packages (from tmap) (1.5.3)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from tmap) (1.10.1)
# Collecting umap-learn (from tmap)
#   Downloading umap-learn-0.5.3.tar.gz (88 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 88.2/88.2 kB 7.7 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: plotly in /usr/local/lib/python3.10/dist-packages (from tmap) (5.13.1)
# Requirement already satisfied: decorator>=4.3.0 in /usr/local/lib/python3.10/dist-packages (from networkx==2.2->tmap) (4.4.2)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=2.2.2->tmap) (1.1.0)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=2.2.2->tmap) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=2.2.2->tmap) (4.41.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=2.2.2->tmap) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=2.2.2->tmap) (23.1)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=2.2.2->tmap) (3.1.0)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=2.2.2->tmap) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=0.23.0->tmap) (2022.7.1)
# Requirement already satisfied: joblib>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=0.19.1->tmap) (1.3.1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=0.19.1->tmap) (3.1.0)
# Requirement already satisfied: patsy>=0.5.2 in /usr/local/lib/python3.10/dist-packages (from statsmodels>=0.9.0->tmap) (0.5.3)
# Requirement already satisfied: tenacity>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from plotly->tmap) (8.2.2)
# Requirement already satisfied: numba>=0.49 in /usr/local/lib/python3.10/dist-packages (from umap-learn->tmap) (0.56.4)
# Collecting pynndescent>=0.5 (from umap-learn->tmap)
#   Downloading pynndescent-0.5.10.tar.gz (1.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 42.4 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: llvmlite<0.40,>=0.39.0dev0 in /usr/local/lib/python3.10/dist-packages (from numba>=0.49->umap-learn->tmap) (0.39.1)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from numba>=0.49->umap-learn->tmap) (67.7.2)
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from patsy>=0.5.2->statsmodels>=0.9.0->tmap) (1.16.0)
# Building wheels for collected packages: tmap, networkx, umap-learn, pynndescent
#   Building wheel for tmap (setup.py) ... done
#   Created wheel for tmap: filename=tmap-1.2.1-py3-none-any.whl size=546598 sha256=23d597896bdf968fc1dcdba76e9a015879a6d4db8b9515c128992681f027e99b
#   Stored in directory: /root/.cache/pip/wheels/f5/87/e3/e65e0a40d6216b176dda331fc29d4327f91184d139baf25b87
#   Building wheel for networkx (setup.py) ... done
#   Created wheel for networkx: filename=networkx-2.2-py2.py3-none-any.whl size=1526919 sha256=c432935fa77081a99b2493a59629b08fe62d9a88aada0d85daf0e2be4d3282d5
#   Stored in directory: /root/.cache/pip/wheels/60/ee/2d/07b325c2cbb2ca33e9ca40ceffa86c4f3fa031955a98219159
#   Building wheel for umap-learn (setup.py) ... done
#   Created wheel for umap-learn: filename=umap_learn-0.5.3-py3-none-any.whl size=82816 sha256=637ceecde20b90a09c5ce7c8e1a7e6e62283ed6e77fdc405e36b944e2906be97
#   Stored in directory: /root/.cache/pip/wheels/a0/e8/c6/a37ea663620bd5200ea1ba0907ab3c217042c1d035ef606acc
#   Building wheel for pynndescent (setup.py) ... done
#   Created wheel for pynndescent: filename=pynndescent-0.5.10-py3-none-any.whl size=55622 sha256=c3e84001bd6ee389205faac04b60f6b62327dc46116d84a3e5684ac7f840a818
#   Stored in directory: /root/.cache/pip/wheels/4a/38/5d/f60a40a66a9512b7e5e83517ebc2d1b42d857be97d135f1096
# Successfully built tmap networkx umap-learn pynndescent
# Installing collected packages: rdkit-pypi, networkx, pynndescent, umap-learn, tmap
#   Attempting uninstall: networkx
#     Found existing installation: networkx 3.1
#     Uninstalling networkx-3.1:
#       Successfully uninstalled networkx-3.1
# Successfully installed networkx-2.2 pynndescent-0.5.10 rdkit-pypi-2022.9.5 tmap-1.2.1 umap-learn-0.5.3
# Collecting git+https://github.com/reymond-group/map4@v1.0
#   Cloning https://github.com/reymond-group/map4 (to revision v1.0) to /tmp/pip-req-build-6himnqmt
#   Running command git clone --filter=blob:none --quiet https://github.com/reymond-group/map4 /tmp/pip-req-build-6himnqmt
#   Running command git checkout -q 1457602793f0438a77ee9578ef89ab9a20840c00
#   Resolved https://github.com/reymond-group/map4 to commit 1457602793f0438a77ee9578ef89ab9a20840c00
#   Preparing metadata (setup.py) ... done
# Collecting faerun (from MAP4==1.0)
#   Downloading faerun-0.4.7-py3-none-any.whl (65 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 65.9/65.9 kB 1.3 MB/s eta 0:00:00
# Collecting mhfp (from MAP4==1.0)
#   Downloading mhfp-1.9.6-py3-none-any.whl (9.7 kB)
# Requirement already satisfied: matplotlib>=3.0.2 in /usr/local/lib/python3.10/dist-packages (from faerun->MAP4==1.0) (3.7.1)
# Requirement already satisfied: Jinja2>=2.10 in /usr/local/lib/python3.10/dist-packages (from faerun->MAP4==1.0) (3.1.2)
# Collecting ujson>=1.35 (from faerun->MAP4==1.0)
#   Downloading ujson-5.8.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (53 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 53.9/53.9 kB 1.4 MB/s eta 0:00:00
# Requirement already satisfied: numpy>=1.15.4 in /usr/local/lib/python3.10/dist-packages (from faerun->MAP4==1.0) (1.22.4)
# Collecting colour>=0.1.5 (from faerun->MAP4==1.0)
#   Downloading colour-0.1.5-py2.py3-none-any.whl (23 kB)
# Collecting CherryPy>=18.1.0 (from faerun->MAP4==1.0)
#   Downloading CherryPy-18.8.0-py2.py3-none-any.whl (348 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 348.4/348.4 kB 21.9 MB/s eta 0:00:00
# Requirement already satisfied: pandas>=0.24.2 in /usr/local/lib/python3.10/dist-packages (from faerun->MAP4==1.0) (1.5.3)
# Collecting cheroot>=8.2.1 (from CherryPy>=18.1.0->faerun->MAP4==1.0)
#   Downloading cheroot-10.0.0-py3-none-any.whl (101 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 101.6/101.6 kB 13.9 MB/s eta 0:00:00
# Collecting portend>=2.1.1 (from CherryPy>=18.1.0->faerun->MAP4==1.0)
#   Downloading portend-3.2.0-py3-none-any.whl (5.3 kB)
# Requirement already satisfied: more-itertools in /usr/local/lib/python3.10/dist-packages (from CherryPy>=18.1.0->faerun->MAP4==1.0) (9.1.0)
# Collecting zc.lockfile (from CherryPy>=18.1.0->faerun->MAP4==1.0)
#   Downloading zc.lockfile-3.0.post1-py3-none-any.whl (9.8 kB)
# Collecting jaraco.collections (from CherryPy>=18.1.0->faerun->MAP4==1.0)
#   Downloading jaraco.collections-4.3.0-py3-none-any.whl (11 kB)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from Jinja2>=2.10->faerun->MAP4==1.0) (2.1.3)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.0.2->faerun->MAP4==1.0) (1.1.0)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.0.2->faerun->MAP4==1.0) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.0.2->faerun->MAP4==1.0) (4.41.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.0.2->faerun->MAP4==1.0) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.0.2->faerun->MAP4==1.0) (23.1)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.0.2->faerun->MAP4==1.0) (8.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.0.2->faerun->MAP4==1.0) (3.1.0)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.0.2->faerun->MAP4==1.0) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=0.24.2->faerun->MAP4==1.0) (2022.7.1)
# Collecting jaraco.functools (from cheroot>=8.2.1->CherryPy>=18.1.0->faerun->MAP4==1.0)
#   Downloading jaraco.functools-3.8.0-py3-none-any.whl (8.2 kB)
# Collecting tempora>=1.8 (from portend>=2.1.1->CherryPy>=18.1.0->faerun->MAP4==1.0)
#   Downloading tempora-5.5.0-py3-none-any.whl (13 kB)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7->matplotlib>=3.0.2->faerun->MAP4==1.0) (1.16.0)
# Collecting jaraco.text (from jaraco.collections->CherryPy>=18.1.0->faerun->MAP4==1.0)
#   Downloading jaraco.text-3.11.1-py3-none-any.whl (11 kB)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from zc.lockfile->CherryPy>=18.1.0->faerun->MAP4==1.0) (67.7.2)
# Collecting jaraco.context>=4.1 (from jaraco.text->jaraco.collections->CherryPy>=18.1.0->faerun->MAP4==1.0)
#   Downloading jaraco.context-4.3.0-py3-none-any.whl (5.3 kB)
# Collecting autocommand (from jaraco.text->jaraco.collections->CherryPy>=18.1.0->faerun->MAP4==1.0)
#   Downloading autocommand-2.2.2-py3-none-any.whl (19 kB)
# Requirement already satisfied: inflect in /usr/local/lib/python3.10/dist-packages (from jaraco.text->jaraco.collections->CherryPy>=18.1.0->faerun->MAP4==1.0) (6.0.5)
# Requirement already satisfied: pydantic<2,>=1.9.1 in /usr/local/lib/python3.10/dist-packages (from inflect->jaraco.text->jaraco.collections->CherryPy>=18.1.0->faerun->MAP4==1.0) (1.10.11)
# Requirement already satisfied: typing-extensions>=4.2.0 in /usr/local/lib/python3.10/dist-packages (from pydantic<2,>=1.9.1->inflect->jaraco.text->jaraco.collections->CherryPy>=18.1.0->faerun->MAP4==1.0) (4.7.1)
# Building wheels for collected packages: MAP4
#   Building wheel for MAP4 (setup.py) ... done
#   Created wheel for MAP4: filename=MAP4-1.0-py3-none-any.whl size=4408 sha256=b11902ed0e849426e738411c4c03ab1d205245e51cb47c3af75660073203de09
#   Stored in directory: /tmp/pip-ephem-wheel-cache-jyswvezc/wheels/e6/a2/62/981cb1bebffea0fc09df07a2b59e398e29c662504b91c27e83
# Successfully built MAP4
# Installing collected packages: mhfp, colour, zc.lockfile, ujson, jaraco.functools, jaraco.context, autocommand, tempora, cheroot, portend, jaraco.text, jaraco.collections, CherryPy, faerun, MAP4
# Successfully installed CherryPy-18.8.0 MAP4-1.0 autocommand-2.2.2 cheroot-10.0.0 colour-0.1.5 faerun-0.4.7 jaraco.collections-4.3.0 jaraco.context-4.3.0 jaraco.functools-3.8.0 jaraco.text-3.11.1 mhfp-1.9.6 portend-3.2.0 tempora-5.5.0 ujson-5.8.0 zc.lockfile-3.0.post1
# Cloning into 'Similarity_screen_apelin'...
# remote: Enumerating objects: 42, done.
# remote: Counting objects: 100% (42/42), done.
# remote: Compressing objects: 100% (37/37), done.
# remote: Total 42 (delta 11), reused 31 (delta 4), pack-reused 0
# Receiving objects: 100% (42/42), 25.13 MiB | 24.69 MiB/s, done.
# Resolving deltas: 100% (11/11), done.
# Updating files: 100% (27/27), done.

# %%
#@title **0. Input Package**
import math
import numpy as np
import pandas as pd
from rdkit import Chem
import sys
import os
import glob
import pickle
sys.path.append('./Similarity_screen_apelin/Mol2DSimi')
from Similarity_search import simi_search

# %%
#@title **1. Input SMILES**
#@markdown Enter the ligand **< ID >** and **< SMILES >** to be screened. \

query_SMILES = "S(=O)(=O)(Nc1n(-c2c(OC)cccc2OC)c(-c2cc(C)cnc2)nn1)[C@H]([C@H](C)c1ncc(C)cn1)C" #@param {type:"string"}
query_ID = 'AMG 986' #@param {type:"string"}

Ligand_ID = "CMF-019" #@param {type:"string"}
Ligand_SMILES = "CC(C)C[C@H](NC(C1=CC=C2C(N=C(CC3=CC=CS3)N2C(CC)CC)=C1)=O)CC(O)=O" #@param {type:"string"}


search = simi_search(data=None, smiles_col=smiles_col, ID_col=ID_col,
                     active_col=active_col, model_path = './Similarity_screen_apelin/Model',
                     input_smiles=Ligand_SMILES, id_name = Ligand_ID,
                     query_smiles=query_SMILES, query_name = query_ID)
search.fit()

filter_data = search.data_filter
display(filter_data.head())
# Out:
#                                               SMILES       ID  Active  \
# 0  CC(C)C[C@H](NC(C1=CC=C2C(N=C(CC3=CC=CS3)N2C(CC...  CMF-019       0
#
#                                               ROMol  tanimoto_avalon  \
# 0  <rdkit.Chem.rdchem.Mol object at 0x7e6bbe929e70>         0.387405
#
#    tanimoto_maccs  tanimoto_ecfp2  tanimoto_ecfp4  tanimoto_ecfp6  \
# 0             0.4        0.206897        0.113208        0.081081
#
#    tanimoto_fcfp2  ...  dice_ecfp2  dice_ecfp4  dice_ecfp6  dice_fcfp2  \
# 0        0.016129  ...    0.342857     0.20339        0.15    0.031746
#
#    dice_fcfp4  dice_fcfp6  dice_rdk5  dice_rdk6  dice_rdk7  dice_map4
# 0    0.018519    0.013158   0.327968   0.423946    0.39617   0.560566
#
# [1 rows x 28 columns]
# [07:41:28] WARNING: ../src/learner.cc:553:
#   If you are loading a serialized model (like pickle in Python, RDS in R) generated by
#   older XGBoost, please export the model by calling `Booster.save_model` from that version
#   first, then load it back in current version. See:
#
#     https://xgboost.readthedocs.io/en/latest/tutorials/saving_model.html
#
#   for more details about differences between saving model and serializing.
#          tanimoto_avalon  tanimoto_maccs  tanimoto_ecfp2  tanimoto_ecfp4  \
# CMF-019         0.387405             0.4        0.206897        0.113208
#
#          tanimoto_ecfp6  tanimoto_fcfp2  tanimoto_fcfp4  tanimoto_fcfp6  \
# CMF-019        0.081081        0.016129        0.009346        0.006623
#
#          tanimoto_rdk5  tanimoto_rdk6  tanimoto_rdk7  tanimoto_map4  Pred  \
# CMF-019       0.196149       0.268992       0.247015       0.389435     1
#
#             Proba
# CMF-019  0.884033

# %%
#@title **2. Input Database**
#@markdown Enter the ligand **< ID >** and **< SMILES >** to be screened. \

query_SMILES = "S(=O)(=O)(Nc1n(-c2c(OC)cccc2OC)c(-c2cc(C)cnc2)nn1)[C@H]([C@H](C)c1ncc(C)cn1)C" #@param {type:"string"}
query_ID = 'AMG 986' #@param {type:"string"}


#@markdown Enter the information of search database. \

data_path = '/content/Similarity_screen_apelin/Data/similarity.csv' #@param {type:"string"}
smiles_col = "smiles" #@param {type:"string"}
ID_col = "ID" #@param {type:"string"}
active_col = "Active" #@param {type:"string"}

data = pd.read_csv(data_path)
search = simi_search(data=data, smiles_col=smiles_col, ID_col=ID_col,
                     active_col=active_col, model_path = './Similarity_screen_apelin/Model',
                     query_smiles=query_SMILES, query_name = query_ID)
search.fit()



filter_data = search.data_filter
display(filter_data.head())
# Out:
#            ID                                             smiles  Active  \
# 0     CMF-019  CC(C)C[C@H](NC(C1=CC=C2C(N=C(CC3=CC=CS3)N2C(CC...       0
# 1     AMG 986  S(=O)(=O)(Nc1n(-c2c(OC)cccc2OC)c(-c2cc(C)cnc2)...       0
# 2  BMS-986224  O=C1NC(COCC)=C(C2=C(OC)C=CC=C2OC)C(O)=C1C3=NN=...       0
#
#                                               ROMol  tanimoto_avalon  \
# 0  <rdkit.Chem.rdchem.Mol object at 0x7e6bbe73da80>         0.387405
# 1  <rdkit.Chem.rdchem.Mol object at 0x7e6bbe73d700>         1.000000
# 2  <rdkit.Chem.rdchem.Mol object at 0x7e6bbe73db60>         0.445693
#
#    tanimoto_maccs  tanimoto_ecfp2  tanimoto_ecfp4  tanimoto_ecfp6  \
# 0        0.400000        0.206897        0.113208        0.081081
# 1        1.000000        1.000000        1.000000        1.000000
# 2        0.450549        0.250000        0.165049        0.124138
#
#    tanimoto_fcfp2  ...  dice_ecfp2  dice_ecfp4  dice_ecfp6  dice_fcfp2  \
# 0        0.016129  ...    0.342857    0.203390    0.150000    0.031746
# 1        0.035088  ...    1.000000    1.000000    1.000000    0.067797
# 2        0.016129  ...    0.400000    0.283333    0.220859    0.031746
#
#    dice_fcfp4  dice_fcfp6  dice_rdk5  dice_rdk6  dice_rdk7  dice_map4
# 0    0.018519    0.013158   0.327968   0.423946   0.396170   0.560566
# 1    0.038462    0.013333   1.000000   1.000000   1.000000   1.000000
# 2    0.018182    0.012903   0.417642   0.530504   0.473931   0.599834
#
# [3 rows x 28 columns]
# [07:43:58] WARNING: ../src/learner.cc:553:
#   If you are loading a serialized model (like pickle in Python, RDS in R) generated by
#   older XGBoost, please export the model by calling `Booster.save_model` from that version
#   first, then load it back in current version. See:
#
#     https://xgboost.readthedocs.io/en/latest/tutorials/saving_model.html
#
#   for more details about differences between saving model and serializing.
#             tanimoto_avalon  tanimoto_maccs  tanimoto_ecfp2  tanimoto_ecfp4  \
# CMF-019            0.387405        0.400000        0.206897        0.113208
# AMG 986            1.000000        1.000000        1.000000        1.000000
# BMS-986224         0.445693        0.450549        0.250000        0.165049
#
#             tanimoto_ecfp6  tanimoto_fcfp2  tanimoto_fcfp4  tanimoto_fcfp6  \
# CMF-019           0.081081        0.016129        0.009346        0.006623
# AMG 986           1.000000        0.035088        0.019608        0.006711
# BMS-986224        0.124138        0.016129        0.009174        0.006494
#
#             tanimoto_rdk5  tanimoto_rdk6  tanimoto_rdk7  tanimoto_map4  Pred  \
# CMF-019          0.196149       0.268992       0.247015       0.389435     1
# AMG 986          1.000000       1.000000       1.000000       1.000000     1
# BMS-986224       0.263936       0.361011       0.310557       0.428402     1
#
#                Proba
# CMF-019     0.884033
# AMG 986     0.999570
# BMS-986224  0.949371
